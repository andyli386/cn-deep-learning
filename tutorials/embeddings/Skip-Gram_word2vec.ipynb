# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print(type(words))
# Out:
# <class 'list'>

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
threshold = 1e-5
word_counts = Counter(int_words)
#print(word_counts)
total_count = len(int_words)
freqs = {word:count/total_count for word, count in word_counts.items()}
p_drop = {word:1-np.sqrt(threshold/freqs[word]) for word in word_counts}
## Your code here
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: 无法创建目录"checkpoints": 文件已存在

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6759 0.1958 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6344 0.1895 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5190 0.1912 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6169 0.1901 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5336 0.1891 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5367 0.1896 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5729 0.1895 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5451 0.1893 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4580 0.1902 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4300 0.1897 sec/batch
# Nearest to five: turgidson, civilization, close, rebuilt, fremont, ackroyd, wind, osf,
# Nearest to of: allegation, lenr, berliner, tchaikovsky, rubra, precognition, ofc, manners,
# Nearest to than: objector, balzac, lorids, feist, level, detailed, conforms, bacteria,
# Nearest to up: finn, moltke, transmits, sandstone, nursia, dame, gestalt, chechen,
# Nearest to only: vernaculars, ma, tire, vince, frisii, lani, truncation, eastwards,
# Nearest to after: tribal, mafiosi, biostatistics, bibliographies, burleigh, infrastructure, golfers, haemophilus,
# Nearest to s: rebel, hayden, kowloon, anh, heralded, shilton, discharged, futurism,
# Nearest to however: husband, obsolescent, motorised, abarat, lorids, somewhat, lucien, protruding,
# Nearest to report: career, kindergartens, ooc, rascal, louisa, gallo, rosenbaum, undaunted,
# Nearest to hit: unisys, connections, heylin, konstantin, nobles, disappearing, sends, hejira,
# Nearest to universe: flunitrazepam, ludwig, caribe, ats, nuremberg, cockroach, walk, wastage,
# Nearest to instance: down, links, irenaeus, scientific, three, internationalization, crossword, madame,
# Nearest to professional: fnc, arise, cadaver, federal, imperator, spinoffs, excommunicates, journal,
# Nearest to channel: kumquats, filters, compensates, relative, firebrand, developers, acadians, discourses,
# Nearest to governor: auditioned, litigants, folger, hashemite, upgraded, brisk, correspondence, elbridge,
# Nearest to frac: rejection, ruskin, warwickshire, reorganization, burdens, raises, extravagant, clerical,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4667 0.1974 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3632 0.1909 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3248 0.1903 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2174 0.1904 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2118 0.1904 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1582 0.1906 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1225 0.1904 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0866 0.1896 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0364 0.1899 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9671 0.1903 sec/batch
# Nearest to five: rebuilt, close, civilization, wind, ackroyd, turgidson, fremont, rate,
# Nearest to of: allegation, unclear, friendly, tchaikovsky, manners, ofc, each, defined,
# Nearest to than: level, objector, detailed, feist, submarine, balzac, health, the,
# Nearest to up: transmits, chechen, dame, offense, integration, campaign, cruise, rspca,
# Nearest to only: vision, ma, vince, tire, hinges, vernaculars, addition, movies,
# Nearest to after: tribal, infrastructure, particular, mafiosi, bibliographies, committing, stayed, burleigh,
# Nearest to s: rebel, discharged, hayden, clarify, facilities, traffic, emphasis, concise,
# Nearest to however: husband, somewhat, per, denmark, assertion, people, lucien, motorised,
# Nearest to report: career, kindergartens, occurred, ooc, gallo, louisa, varela, become,
# Nearest to hit: connections, nobles, wherever, hejira, disappearing, sends, because, unisys,
# Nearest to universe: flunitrazepam, appears, walk, caribe, antiprisms, ludwig, cockroach, low,
# Nearest to instance: down, links, scientific, three, text, madame, crossword, experienced,
# Nearest to professional: arise, federal, rejected, spinoffs, counter, excuse, comprised, fnc,
# Nearest to channel: relative, compensates, kumquats, filters, developers, acadians, unsuitable, storms,
# Nearest to governor: auditioned, upgraded, litigants, correspondence, folger, lesser, final, perspective,
# Nearest to frac: rejection, raises, ruskin, reorganization, warwickshire, rulers, extravagant, difficulty,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9490 0.1917 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9094 0.1904 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8903 0.1899 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8669 0.1905 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8031 0.1898 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8275 0.1904 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7957 0.1909 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8087 0.1898 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7833 0.1901 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7950 0.1903 sec/batch
# Nearest to five: rebuilt, ackroyd, wind, rate, turgidson, close, civilization, samuel,
# Nearest to of: allegation, manners, ofc, contradiction, tchaikovsky, comprised, analogous, mix,
# Nearest to than: level, objector, feist, detailed, bacteria, balzac, lorids, submarine,
# Nearest to up: transmits, integration, campaign, dame, converted, offense, goddess, chechen,
# Nearest to only: tire, vision, hinges, frisii, multinational, vernaculars, pirates, vince,
# Nearest to after: tribal, infrastructure, stayed, bibliographies, mafiosi, committing, golfers, disappointment,
# Nearest to s: rebel, shilton, discharged, kowloon, facilities, concise, clarify, heralded,
# Nearest to however: husband, somewhat, assertion, oxidation, motorised, enormous, denmark, subjective,
# Nearest to report: career, kindergartens, gallo, ooc, louisa, varela, thirties, disciple,
# Nearest to hit: connections, nobles, disappearing, hejira, sends, wherever, unisys, konstantin,
# Nearest to universe: appears, flunitrazepam, walk, advent, nuremberg, ludwig, antiprisms, internationalization,
# Nearest to instance: down, scientific, flight, links, madame, crossword, irenaeus, experienced,
# Nearest to professional: arise, spinoffs, federal, excuse, tiny, rejected, win, evenings,
# Nearest to channel: relative, compensates, developers, filters, storms, theorized, kumquats, acadians,
# Nearest to governor: upgraded, correspondence, auditioned, provinces, lesser, perspective, usgs, complied,
# Nearest to frac: warwickshire, rejection, raises, rulers, ruskin, difficulty, measure, reorganization,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7687 0.1932 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7488 0.1894 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7414 0.1906 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7477 0.1905 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7329 0.1950 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7169 0.1985 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6808 0.1977 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7174 0.1972 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6906 0.1990 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6523 0.2014 sec/batch
# Nearest to five: rebuilt, samuel, ackroyd, zero, reverend, eight, akron, fremont,
# Nearest to of: manners, ofc, allegation, comprised, tchaikovsky, berliner, vikings, gru,
# Nearest to than: level, objector, feist, lorids, balzac, bacteria, conforms, tab,
# Nearest to up: transmits, moltke, goddess, dame, finn, castles, campaign, calvinist,
# Nearest to only: tire, vernaculars, hinges, multinational, frisii, lani, vision, pirates,
# Nearest to after: tribal, mafiosi, infrastructure, bibliographies, stayed, disappointment, heian, committing,
# Nearest to s: rebel, shilton, discharged, heralded, kowloon, spouses, sovereignty, futurism,
# Nearest to however: husband, assertion, somewhat, subjective, inspected, lorids, protruding, oxidation,
# Nearest to report: career, kindergartens, louisa, gallo, ooc, paws, varela, undaunted,
# Nearest to hit: connections, konstantin, nobles, hejira, sends, unisys, wherever, disappearing,
# Nearest to universe: flunitrazepam, appears, nuremberg, advent, antiprisms, gropius, hymn, ptolemaic,
# Nearest to instance: scientific, down, flight, madame, crossword, assizes, transistors, irenaeus,
# Nearest to professional: spinoffs, arise, federal, win, fnc, evenings, excuse, excommunicates,
# Nearest to channel: compensates, filters, relative, developers, kumquats, reelected, kulaks, theorized,
# Nearest to governor: auditioned, upgraded, correspondence, independence, provinces, litigants, was, hashemite,
# Nearest to frac: warwickshire, ruskin, measure, difficulty, raises, reorganization, ircnet, clerical,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6648 0.2047 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6592 0.2007 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6231 0.1950 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6332 0.1930 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6512 0.1921 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6351 0.1922 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5827 0.1410 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5597 0.1923 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5230 0.1924 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5104 0.1919 sec/batch
# Nearest to five: zero, eight, samuel, rebuilt, reverend, poet, akron, two,
# Nearest to of: allegation, ofc, manners, vikings, gru, comprised, lenr, jewell,
# Nearest to than: level, lorids, objector, bacteria, feist, balzac, tab, conforms,
# Nearest to up: transmits, moltke, goddess, observes, castles, fairclough, finn, spiritually,
# Nearest to only: tire, vernaculars, hinges, multinational, lani, frisii, skits, vision,
# Nearest to after: tribal, mafiosi, stayed, bibliographies, infrastructure, disappointment, heian, committing,
# Nearest to s: rebel, shilton, brigham, heralded, kowloon, discharged, spouses, landis,
# Nearest to however: husband, assertion, subjective, somewhat, lorids, obsolescent, oxidation, motorised,
# Nearest to report: career, kindergartens, ooc, louisa, archive, gallo, varela, undaunted,
# Nearest to hit: connections, hejira, konstantin, nobles, unisys, sends, geometrically, winding,
# Nearest to universe: appears, flunitrazepam, nuremberg, caribe, advent, antiprisms, simplicius, nyos,
# Nearest to instance: scientific, assizes, transistors, down, text, internationalization, wet, crossword,
# Nearest to professional: spinoffs, win, terrence, arise, evenings, excuse, vaughan, federal,
# Nearest to channel: compensates, developers, filters, reelected, kulaks, kumquats, relative, slovenes,
# Nearest to governor: auditioned, independence, provinces, folger, complied, litigants, queen, correspondence,
# Nearest to frac: warwickshire, measure, ruskin, ircnet, number, difficulty, raises, poignant,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5279 0.1938 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4966 0.1901 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4777 0.1904 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5362 0.1917 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4992 0.1916 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5007 0.1913 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4521 0.1962 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3832 0.1961 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4335 0.1896 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4269 0.1864 sec/batch
# Nearest to five: zero, ackroyd, fremont, rebuilt, akron, eight, two, rate,
# Nearest to of: allegation, manners, ofc, gru, hindi, lenr, romanesque, tchaikovsky,
# Nearest to than: level, lorids, objector, bacteria, feist, risk, medium, conforms,
# Nearest to up: transmits, moltke, observes, goddess, fairclough, reductionist, come, offense,
# Nearest to only: tire, lani, hinges, vernaculars, multinational, skits, frisii, vision,
# Nearest to after: tribal, mafiosi, stayed, bibliographies, ballpark, disappointment, heian, committing,
# Nearest to s: shilton, heralded, rebel, brigham, kowloon, landis, mumbai, discharged,
# Nearest to however: subjective, assertion, husband, obsolescent, lorids, somewhat, oxidation, increases,
# Nearest to report: career, kindergartens, varela, gallo, archive, paws, summits, undaunted,
# Nearest to hit: connections, hejira, konstantin, winding, catcher, geometrically, nobles, pratchett,
# Nearest to universe: appears, flunitrazepam, conscious, simplicius, caribe, calculated, nyos, accepts,
# Nearest to instance: scientific, transistors, circuits, assizes, doesn, crossword, text, experimentation,
# Nearest to professional: win, spinoffs, jiao, cadaver, evenings, vaughan, adduced, terrence,
# Nearest to channel: filters, compensates, developers, kulaks, reelected, kumquats, relative, storms,
# Nearest to governor: independence, provinces, folger, auditioned, complied, brisk, jain, litigants,
# Nearest to frac: measure, number, ruskin, warwickshire, difficulty, ircnet, plugs, sqrt,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4264 0.1889 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4064 0.1874 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4359 0.1884 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3872 0.1878 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4223 0.1892 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4318 0.1922 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3959 0.1925 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3980 0.1893 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4341 0.1910 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3704 0.1972 sec/batch
# Nearest to five: zero, ackroyd, two, eight, akron, fremont, m, dawson,
# Nearest to of: ofc, gru, lenr, allegation, manners, hindi, romanesque, frictions,
# Nearest to than: level, lorids, objector, conforms, feist, tab, bacteria, risk,
# Nearest to up: transmits, moltke, offense, observes, come, reductionist, buses, waist,
# Nearest to only: lani, vernaculars, tire, hinges, skits, vision, frisii, lingerie,
# Nearest to after: tribal, mafiosi, stayed, bibliographies, heian, disappointment, he, ballpark,
# Nearest to s: shilton, brigham, rebel, heralded, landis, phonograph, chinatown, kowloon,
# Nearest to however: husband, subjective, obsolescent, assertion, lorids, somewhat, protruding, enormous,
# Nearest to report: paws, career, kindergartens, archive, wiki, undaunted, varela, summits,
# Nearest to hit: connections, hejira, winding, catcher, konstantin, pratchett, caray, geometrically,
# Nearest to universe: appears, flunitrazepam, simplicius, conscious, diatessaron, accepts, caribe, tending,
# Nearest to instance: transistors, circuits, scientific, experimentation, rj, assizes, internationalization, simplicity,
# Nearest to professional: win, spinoffs, jiao, dennis, terrence, cadaver, adduced, affiliates,
# Nearest to channel: developers, filters, compensates, kulaks, firebrand, reelected, railhead, kumquats,
# Nearest to governor: independence, provinces, folger, vote, silesia, auditioned, complied, brisk,
# Nearest to frac: measure, number, sqrt, ruskin, difficulty, ircnet, dx, warwickshire,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3678 0.2000 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4095 0.1954 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3499 0.1925 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3661 0.1922 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3707 0.1947 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3858 0.1927 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3868 0.1920 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3633 0.1938 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3359 0.1970 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3276 0.1920 sec/batch
# Nearest to five: zero, two, m, eight, ackroyd, akron, fremont, four,
# Nearest to of: ofc, gru, creoles, lenr, ote, hindi, dependencies, lanka,
# Nearest to than: level, lorids, objector, conforms, risk, feist, cyanobacteria, bacteria,
# Nearest to up: moltke, castles, transmits, campaign, silty, buses, reductionist, finn,
# Nearest to only: lani, tire, hinges, vernaculars, skits, counterweight, vision, frisii,
# Nearest to after: tribal, mafiosi, stayed, heian, golfers, sofie, logrus, bibliographies,
# Nearest to s: shilton, brigham, chinatown, heralded, concise, rebel, phonograph, floss,
# Nearest to however: assertion, subjective, husband, somewhat, lorids, obsolescent, increases, protruding,
# Nearest to report: summits, archive, wiki, paws, lollapalooza, varela, kindergartens, rascal,
# Nearest to hit: connections, winding, hejira, catcher, konstantin, caray, pratchett, geometrically,
# Nearest to universe: appears, diatessaron, conscious, accepts, tending, simplicius, flunitrazepam, instincts,
# Nearest to instance: experimentation, transistors, nuisances, circuits, scientific, simplicity, rj, assizes,
# Nearest to professional: win, spinoffs, jiao, cadaver, dennis, terrence, adduced, affiliates,
# Nearest to channel: filters, developers, compensates, eliminate, rtp, kulaks, novell, railhead,
# Nearest to governor: provinces, folger, vote, independence, brisk, veto, traynor, auditioned,
# Nearest to frac: measure, sqrt, number, ruskin, rotation, technetium, denominator, denotes,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3428 0.1933 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3124 0.1910 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3515 0.1912 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3878 0.1908 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4055 0.1903 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2985 0.1909 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2920 0.1879 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3420 0.1901 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2324 0.1893 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2839 0.1914 sec/batch
# Nearest to five: zero, two, eight, four, years, ackroyd, rate, akron,
# Nearest to of: ofc, creoles, gru, ote, frictions, hindi, tchaikovsky, lanka,
# Nearest to than: level, lorids, conforms, objector, feist, balzac, looney, tab,
# Nearest to up: transmits, moltke, come, castles, finn, reductionist, campaign, offense,
# Nearest to only: lani, tire, hinges, vernaculars, skits, lingerie, counterweight, amoeba,
# Nearest to after: tribal, stayed, mafiosi, heian, logrus, he, disappointment, golfers,
# Nearest to s: shilton, vaduz, brigham, heralded, chinatown, futurism, phonograph, helens,
# Nearest to however: husband, assertion, lorids, obsolescent, somewhat, subjective, increases, margarine,
# Nearest to report: summits, archive, varela, lollapalooza, paws, failure, kindergartens, wiki,
# Nearest to hit: connections, hejira, catcher, winding, konstantin, caray, pratchett, mpg,
# Nearest to universe: appears, diatessaron, conscious, instincts, simplicius, forti, ptolemaic, tending,
# Nearest to instance: nuisances, transistors, rj, circuits, doesn, scientific, experimentation, simplicity,
# Nearest to professional: win, spinoffs, dennis, affiliates, terrence, jiao, excommunicates, cadaver,
# Nearest to channel: developers, filters, compensates, rtp, railhead, novell, eliminate, unsuitable,
# Nearest to governor: vote, folger, brisk, provinces, senator, veto, traynor, minh,
# Nearest to frac: sqrt, measure, denominator, cdot, cos, mathbf, number, denotes,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3239 0.1968 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2776 0.1933 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3376 0.0945 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2347 0.1987 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2141 0.1961 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2129 0.1971 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2168 0.1943 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2409 0.1938 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1991 0.1947 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1927 0.1946 sec/batch
# Nearest to five: zero, two, eight, four, years, rate, m, fremont,
# Nearest to of: ofc, gru, creoles, romanesque, hindi, dependencies, lanka, frictions,
# Nearest to than: level, lorids, feist, objector, conforms, balzac, medium, cyanobacteria,
# Nearest to up: moltke, transmits, come, campaign, offense, castles, finn, waist,
# Nearest to only: lani, tire, hinges, vernaculars, lingerie, skits, counterweight, amoeba,
# Nearest to after: stayed, mafiosi, heian, tribal, ballpark, he, sofie, logrus,
# Nearest to s: shilton, phonograph, vaduz, chinatown, heralded, helens, and, brigham,
# Nearest to however: husband, assertion, lorids, obsolescent, petrochemical, increases, monist, subjective,
# Nearest to report: summits, archive, varela, wiki, undaunted, failure, lollapalooza, occurred,
# Nearest to hit: connections, catcher, winding, hejira, pratchett, konstantin, mpg, obituary,
# Nearest to universe: diatessaron, appears, conscious, forti, simplicius, oversimplified, predicted, ludwig,
# Nearest to instance: experimentation, nuisances, transistors, rj, circuits, velikovsky, transponder, leptons,
# Nearest to professional: win, spinoffs, jiao, affiliates, dennis, terrence, cadaver, buick,
# Nearest to channel: developers, filters, compensates, rtp, railhead, novell, bbc, reelected,
# Nearest to governor: vote, folger, veto, complied, brisk, senator, minh, litigants,
# Nearest to frac: sqrt, measure, denominator, mathbf, cdot, cos, dx, ruskin,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2878 0.1976 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2124 0.1946 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2035 0.1920 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1345 0.1910 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1730 0.1898 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1582 0.1878 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1715 0.1882 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1729 0.1874 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1854 0.1873 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1487 0.1874 sec/batch
# Nearest to five: zero, two, four, eight, rate, m, years, ackroyd,
# Nearest to of: ofc, gru, example, dependencies, analogous, astrophysicists, creoles, fissile,
# Nearest to than: level, lorids, objector, feist, conforms, medium, balzac, looney,
# Nearest to up: come, transmits, moltke, offense, finn, typing, cruise, observes,
# Nearest to only: lani, tire, hinges, skits, amoeba, vernaculars, over, counterweight,
# Nearest to after: heian, mafiosi, ballpark, stayed, sofie, golfers, tribal, logrus,
# Nearest to s: shilton, phonograph, vaduz, chinatown, heralded, and, brigham, radiator,
# Nearest to however: lorids, husband, increases, somewhat, assertion, monist, petrochemical, enormous,
# Nearest to report: archive, summits, varela, wiki, undaunted, lollapalooza, failure, enrollments,
# Nearest to hit: connections, catcher, winding, hejira, pratchett, disoriented, mpg, konstantin,
# Nearest to universe: diatessaron, bang, conscious, appears, predicted, forti, calculated, oversimplified,
# Nearest to instance: experimentation, velikovsky, nuisances, simplicity, rj, circuits, weaves, doesn,
# Nearest to professional: win, affiliates, jiao, spinoffs, cadaver, buick, terrence, dennis,
# Nearest to channel: developers, rtp, filters, bbc, compensates, novell, kulaks, reelected,
# Nearest to governor: vote, folger, veto, brisk, complied, assembly, senator, litigants,
# Nearest to frac: sqrt, denominator, cos, cdot, number, delta, measure, mathbf,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1711 0.1897 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2138 0.1882 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1695 0.1895 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1478 0.1889 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1920 0.1905 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1736 0.1899 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2001 0.1910 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1568 0.1895 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1507 0.1895 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1770 0.1870 sec/batch
# Nearest to five: zero, two, eight, four, rate, m, years, one,
# Nearest to of: ofc, creoles, astrophysicists, gru, dependencies, fissile, analogous, example,
# Nearest to than: level, lorids, objector, feist, conforms, balzac, looney, medium,
# Nearest to up: come, transmits, observes, moltke, silty, typing, offense, jfduke,
# Nearest to only: tire, lani, hinges, over, vernaculars, lingerie, vernal, skits,
# Nearest to after: heian, sofie, golfers, mafiosi, stayed, tribal, committing, ballpark,
# Nearest to s: shilton, vaduz, phonograph, chinatown, concise, and, floss, heralded,
# Nearest to however: lorids, somewhat, husband, monist, increases, assertion, enormous, inspected,
# Nearest to report: archive, summits, varela, failure, wiki, occurred, lollapalooza, undaunted,
# Nearest to hit: connections, catcher, winding, hejira, disoriented, pratchett, obituary, boy,
# Nearest to universe: diatessaron, predicted, bang, appears, conscious, observed, forti, ptolemaic,
# Nearest to instance: simplicity, nuisances, experimentation, rj, velikovsky, transponder, weaves, copernican,
# Nearest to professional: win, jiao, affiliates, spinoffs, terrence, cadaver, buick, dennis,
# Nearest to channel: developers, compensates, bbc, rtp, filters, novell, kulaks, relay,
# Nearest to governor: vote, veto, folger, assembly, litigants, complied, senator, brisk,
# Nearest to frac: sqrt, denominator, cos, cdot, neq, number, measure, delta,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2011 0.1878 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2106 0.1874 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1614 0.1864 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1825 0.1861 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1628 0.1855 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1406 0.1858 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1670 0.1867 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1311 0.1867 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2069 0.1870 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2198 0.1881 sec/batch
# Nearest to five: zero, two, four, eight, one, years, m, six,
# Nearest to of: ofc, creoles, astrophysicists, frictions, nephew, shigeru, rousseau, gru,
# Nearest to than: level, lorids, feist, objector, balzac, looney, conforms, mulroney,
# Nearest to up: come, transmits, moltke, typing, observes, finn, jfduke, dame,
# Nearest to only: lani, tire, hinges, skits, vernaculars, messiahs, lingerie, over,
# Nearest to after: heian, sofie, he, mafiosi, stayed, golfers, committing, tribal,
# Nearest to s: shilton, vaduz, and, chinatown, phonograph, marley, of, helens,
# Nearest to however: husband, lorids, ottomans, monist, assertion, margarine, almsgiving, enormous,
# Nearest to report: archive, varela, summits, transshipment, failure, enrollments, occurred, lollapalooza,
# Nearest to hit: connections, catcher, winding, hejira, disoriented, pratchett, caray, seated,
# Nearest to universe: diatessaron, bang, predicted, appears, observed, ptolemaic, simplicius, calculated,
# Nearest to instance: simplicity, nuisances, experimentation, velikovsky, rj, transponder, weaves, leptons,
# Nearest to professional: jiao, win, affiliates, cadaver, terrence, buick, federal, haitian,
# Nearest to channel: rtp, compensates, filters, developers, bbc, novell, relay, railhead,
# Nearest to governor: vote, folger, veto, litigants, elbridge, brisk, complied, senator,
# Nearest to frac: denominator, sqrt, cos, measure, cdot, neq, delta, technetium,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2086 0.1883 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1541 0.1861 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1405 0.1855 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1311 0.1870 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0228 0.1868 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1671 0.1866 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1649 0.1865 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1449 0.1865 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1535 0.0359 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1030 0.1860 sec/batch
# Nearest to five: zero, two, four, eight, one, rate, six, years,
# Nearest to of: ofc, creoles, indirection, and, astrophysicists, dependencies, example, fissile,
# Nearest to than: level, lorids, feist, balzac, roughly, looney, medium, jade,
# Nearest to up: come, transmits, typing, moltke, cruise, observes, vayikra, jfduke,
# Nearest to only: lani, tire, hinges, messiahs, vernal, skits, over, lingerie,
# Nearest to after: sofie, heian, golfers, mafiosi, committing, he, disappointment, stayed,
# Nearest to s: vaduz, shilton, and, phonograph, chinatown, marley, of, links,
# Nearest to however: lorids, husband, somewhat, inspected, petrochemical, assertion, increases, connotations,
# Nearest to report: archive, varela, wiki, summits, cnes, occurred, transshipment, lollapalooza,
# Nearest to hit: connections, catcher, hejira, winding, disoriented, pratchett, obituary, seated,
# Nearest to universe: diatessaron, bang, predicted, conscious, monographs, mortals, observed, calculated,
# Nearest to instance: simplicity, nuisances, velikovsky, weaves, experimentation, rj, leptons, circuits,
# Nearest to professional: jiao, affiliates, win, buick, cadaver, terrence, dennis, spinoffs,
# Nearest to channel: compensates, rtp, bbc, developers, filters, railhead, novell, kumquats,
# Nearest to governor: vote, veto, folger, litigants, complied, elbridge, assembly, brisk,
# Nearest to frac: denominator, sqrt, neq, measure, cdot, cos, number, technetium,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1105 0.1887 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0964 0.1864 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1184 0.1864 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0592 0.1865 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0826 0.1866 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0318 0.1887 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0949 0.1898 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0970 0.1892 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1068 0.1880 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0376 0.1891 sec/batch
# Nearest to five: zero, two, four, eight, one, years, six, rate,
# Nearest to of: ofc, astrophysicists, gru, indirection, romanesque, dependencies, example, and,
# Nearest to than: level, lorids, feist, balzac, mulroney, priced, medium, roughly,
# Nearest to up: come, typing, transmits, cruise, moltke, silty, speedup, dumpling,
# Nearest to only: lani, tire, over, hinges, messiahs, vernal, amoeba, rivaled,
# Nearest to after: ballpark, heian, sofie, mafiosi, stayed, committing, wink, he,
# Nearest to s: vaduz, shilton, phonograph, chinatown, and, marley, heralded, moore,
# Nearest to however: lorids, petrochemical, exceed, ottomans, assertion, husband, almsgiving, monist,
# Nearest to report: archive, varela, summits, wiki, occurred, cnes, transshipment, undertakes,
# Nearest to hit: catcher, connections, disoriented, hejira, winding, pratchett, seated, cupid,
# Nearest to universe: diatessaron, bang, predicted, observed, monographs, calculated, forti, oversimplified,
# Nearest to instance: nuisances, simplicity, velikovsky, weaves, experimentation, transponder, loneliness, leptons,
# Nearest to professional: jiao, affiliates, win, buick, cadaver, terrence, lackluster, dennis,
# Nearest to channel: compensates, bbc, rtp, developers, filters, railhead, kumquats, novell,
# Nearest to governor: vote, folger, veto, litigants, complied, assembly, recommendation, brisk,
# Nearest to frac: denominator, sqrt, cos, number, neq, left, measure, cdot,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0441 0.1918 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0396 0.1898 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9976 0.1893 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0572 0.1896 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0619 0.1906 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0131 0.1899 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0574 0.1896 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1290 0.1893 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0221 0.1906 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0295 0.1892 sec/batch
# Nearest to five: zero, two, four, eight, one, six, years, rate,
# Nearest to of: astrophysicists, ofc, dependencies, the, indirection, fissile, example, juba,
# Nearest to than: level, lorids, mulroney, roughly, balzac, medium, priced, looney,
# Nearest to up: come, typing, moltke, transmits, vayikra, speedup, observes, cruise,
# Nearest to only: lani, tire, messiahs, over, a, hinges, vernal, rivaled,
# Nearest to after: wink, ballpark, mafiosi, sofie, heian, committing, golfers, stayed,
# Nearest to s: vaduz, shilton, phonograph, and, chinatown, moore, heralded, marley,
# Nearest to however: petrochemical, monist, lorids, exceed, connotations, husband, inspected, sleeker,
# Nearest to report: archive, varela, occurred, summits, wiki, solicit, undertakes, commission,
# Nearest to hit: catcher, connections, disoriented, hejira, winding, pratchett, seated, caray,
# Nearest to universe: diatessaron, bang, predicted, observed, existence, conscious, calculated, monographs,
# Nearest to instance: simplicity, nuisances, velikovsky, experimentation, weaves, rj, loneliness, transponder,
# Nearest to professional: jiao, affiliates, buick, win, cadaver, terrence, rejected, lackluster,
# Nearest to channel: bbc, compensates, rtp, railhead, kumquats, filters, leandro, maidens,
# Nearest to governor: veto, folger, vote, litigants, complied, assembly, brisk, recommendation,
# Nearest to frac: denominator, left, number, sqrt, neq, cos, sides, measure,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0426 0.1919 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0846 0.1907 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0789 0.1899 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0634 0.1901 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0548 0.1903 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0483 0.1916 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0730 0.1899 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0634 0.1916 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0949 0.1905 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0661 0.1907 sec/batch
# Nearest to five: zero, two, four, one, eight, six, years, seven,
# Nearest to of: the, astrophysicists, and, ofc, romanesque, dependencies, on, creoles,
# Nearest to than: level, lorids, roughly, mulroney, feist, low, balzac, medium,
# Nearest to up: come, vayikra, transmits, moltke, typing, silty, speedup, dumpling,
# Nearest to only: lani, tire, messiahs, over, hinges, vernal, a, rivaled,
# Nearest to after: heian, sofie, mafiosi, antwerp, golfers, he, committing, stayed,
# Nearest to s: vaduz, shilton, and, marley, chinatown, moore, inteligencia, phonograph,
# Nearest to however: exceed, monist, ottomans, lorids, petrochemical, inspected, enormous, margarine,
# Nearest to report: archive, varela, occurred, summits, cnes, transshipment, undertakes, snp,
# Nearest to hit: catcher, connections, disoriented, hejira, winding, seated, cupid, pratchett,
# Nearest to universe: diatessaron, bang, observed, predicted, existence, bohr, calculated, himalayas,
# Nearest to instance: nuisances, simplicity, velikovsky, loneliness, experimentation, transponder, weaves, rj,
# Nearest to professional: jiao, buick, affiliates, win, terrence, cadaver, rejected, haitian,
# Nearest to channel: compensates, bbc, rtp, relay, railhead, filters, maidens, kumquats,
# Nearest to governor: veto, folger, vote, litigants, elbridge, complied, provinces, queen,
# Nearest to frac: denominator, neq, left, cos, sqrt, number, measure, mathbf,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0877 0.1936 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0147 0.1911 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0338 0.1897 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0675 0.1919 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0800 0.1920 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1176 0.1906 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1358 0.1895 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0264 0.1904 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0520 0.1910 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0512 0.1888 sec/batch
# Nearest to five: zero, two, four, eight, one, six, three, seven,
# Nearest to of: the, ofc, and, astrophysicists, romanesque, blacksmith, kuril, on,
# Nearest to than: level, mulroney, feist, roughly, lorids, less, balzac, priced,
# Nearest to up: vayikra, come, moltke, transmits, typing, dame, observes, dumpling,
# Nearest to only: lani, tire, vernal, rivaled, lingerie, hinges, messiahs, brand,
# Nearest to after: committing, he, sofie, heian, mafiosi, wink, ballpark, golfers,
# Nearest to s: vaduz, shilton, and, marley, phonograph, chinatown, inteligencia, of,
# Nearest to however: monist, exceed, petrochemical, ottomans, margarine, connotations, husband, inspected,
# Nearest to report: archive, occurred, varela, transshipment, cnes, snp, gallo, summits,
# Nearest to hit: catcher, connections, hejira, disoriented, winding, caray, cupid, pratchett,
# Nearest to universe: diatessaron, bang, predicted, observed, existence, calculated, ptolemaic, himalayas,
# Nearest to instance: nuisances, simplicity, velikovsky, transponder, leptons, weaves, rj, loneliness,
# Nearest to professional: jiao, buick, affiliates, win, terrence, cadaver, haitian, lackluster,
# Nearest to channel: compensates, bbc, rtp, railhead, maidens, relative, leandro, filters,
# Nearest to governor: folger, veto, vote, elbridge, litigants, joplin, traynor, complied,
# Nearest to frac: denominator, neq, left, cos, sqrt, cdot, mathbf, measure,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9877 0.1881 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0089 0.1864 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0343 0.1869 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0157 0.1875 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0666 0.1859 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0672 0.1726 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9909 0.1868 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9802 0.1862 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0378 0.1864 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9944 0.1855 sec/batch
# Nearest to five: zero, two, four, one, eight, six, three, seven,
# Nearest to of: the, astrophysicists, and, ofc, on, creoles, seu, see,
# Nearest to than: level, roughly, feist, lorids, less, balzac, mulroney, priced,
# Nearest to up: vayikra, come, moltke, transmits, typing, silty, speedup, observes,
# Nearest to only: lani, tire, vernal, over, messiahs, lingerie, hinges, brand,
# Nearest to after: ballpark, sofie, stayed, mafiosi, wink, antwerp, he, committing,
# Nearest to s: vaduz, shilton, and, chinatown, phonograph, of, googolplex, inexplicable,
# Nearest to however: exceed, inspected, monist, connotations, husband, legible, lorids, petrochemical,
# Nearest to report: archive, occurred, varela, cnes, wiki, transshipment, undertakes, snp,
# Nearest to hit: catcher, connections, hejira, disoriented, winding, obituary, devonport, typhoon,
# Nearest to universe: diatessaron, bang, existence, conscious, predicted, himalayas, observed, simplicius,
# Nearest to instance: nuisances, simplicity, experimentation, loneliness, velikovsky, transponder, weaves, leptons,
# Nearest to professional: buick, jiao, affiliates, win, bikes, terrence, lackluster, cadaver,
# Nearest to channel: compensates, bbc, rtp, railhead, maidens, leandro, kumquats, relative,
# Nearest to governor: folger, veto, vote, elbridge, complied, litigants, joplin, senator,
# Nearest to frac: denominator, neq, sqrt, left, mathbf, cos, cdot, number,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9958 0.1881 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9637 0.1853 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0182 0.1862 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0188 0.1861 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0378 0.1853 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0155 0.1857 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9281 0.1853 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9868 0.1857 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9346 0.1860 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0295 0.1846 sec/batch
# Nearest to five: zero, two, four, eight, one, three, six, seven,
# Nearest to of: the, astrophysicists, and, in, on, ofc, dependencies, see,
# Nearest to than: level, one, roughly, lorids, less, priced, balzac, mulroney,
# Nearest to up: come, vayikra, transmits, typing, silty, moltke, speedup, synchronized,
# Nearest to only: a, tire, lani, rivaled, over, messiahs, overtime, vernal,
# Nearest to after: ballpark, mafiosi, golfers, wink, committing, explosions, completed, antwerp,
# Nearest to s: shilton, vaduz, and, chinatown, of, phonograph, marley, inexplicable,
# Nearest to however: exceed, petrochemical, was, connotations, enormous, monist, lorids, inspected,
# Nearest to report: archive, occurred, varela, cnes, undertakes, snp, whatsoever, wiki,
# Nearest to hit: catcher, disoriented, connections, hejira, winding, caray, devonport, keratin,
# Nearest to universe: bang, diatessaron, existence, predicted, observed, calculated, conscious, himalayas,
# Nearest to instance: nuisances, simplicity, velikovsky, loneliness, weaves, transponder, experimentation, histone,
# Nearest to professional: jiao, buick, affiliates, win, practice, bikes, rejected, cadaver,
# Nearest to channel: compensates, bbc, rtp, railhead, leandro, maidens, tak, filters,
# Nearest to governor: veto, folger, elbridge, vote, litigants, complied, recommendation, joplin,
# Nearest to frac: denominator, neq, left, mathbf, sqrt, cos, number, cdot,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9862 0.1870 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9891 0.1841 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9640 0.1842 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0045 0.1847 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0338 0.1840 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9323 0.1847 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0003 0.1847 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9915 0.1847 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9876 0.1850 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0049 0.1845 sec/batch
# Nearest to five: zero, two, four, one, eight, six, three, seven,
# Nearest to of: the, astrophysicists, see, on, and, in, s, ofc,
# Nearest to than: level, mulroney, roughly, priced, less, feist, looney, lorids,
# Nearest to up: come, vayikra, typing, transmits, silty, observes, spiritually, capacity,
# Nearest to only: a, tire, rivaled, lani, over, brand, vernal, messiahs,
# Nearest to after: wink, committing, ballpark, nihilist, sofie, haemophilus, mafiosi, golfers,
# Nearest to s: and, shilton, of, vaduz, phonograph, marley, chinatown, by,
# Nearest to however: was, exceed, connotations, enormous, monist, be, inspected, petrochemical,
# Nearest to report: archive, occurred, wiki, varela, undertakes, cnes, solicit, stm,
# Nearest to hit: catcher, connections, hejira, disoriented, winding, blinking, geometrically, typhoon,
# Nearest to universe: diatessaron, bang, existence, predicted, himalayas, calculated, observed, conscious,
# Nearest to instance: simplicity, velikovsky, experimentation, zoomed, transponder, histone, loneliness, nuisances,
# Nearest to professional: buick, jiao, affiliates, rejected, practice, bikes, cadaver, sanctioned,
# Nearest to channel: compensates, bbc, railhead, rtp, leandro, filters, maidens, kumquats,
# Nearest to governor: veto, folger, elbridge, vote, litigants, complied, joplin, provinces,
# Nearest to frac: denominator, left, mathbf, neq, cos, sqrt, cdot, number,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9960 0.1880 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9884 0.1845 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9759 0.1848 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0006 0.1858 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9947 0.1854 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0037 0.1848 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9768 0.1849 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9809 0.1847 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9767 0.1841 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0220 0.1857 sec/batch
# Nearest to five: two, zero, four, one, eight, three, six, seven,
# Nearest to of: the, in, on, and, s, see, by, astrophysicists,
# Nearest to than: level, less, mulroney, priced, roughly, low, more, feist,
# Nearest to up: come, silty, vayikra, transmits, typing, capacity, moltke, shaking,
# Nearest to only: a, lani, rivaled, not, there, tire, vernal, order,
# Nearest to after: antwerp, heian, mafiosi, committing, sofie, nihilist, golfers, continued,
# Nearest to s: of, vaduz, and, shilton, chinatown, by, phonograph, one,
# Nearest to however: exceed, was, be, enormous, connotations, petrochemical, this, less,
# Nearest to report: archive, occurred, varela, undertakes, wiki, transshipment, cnes, stm,
# Nearest to hit: catcher, connections, hejira, disoriented, obituary, winding, blinking, devonport,
# Nearest to universe: diatessaron, bang, existence, himalayas, ptolemaic, predicted, conscious, televison,
# Nearest to instance: velikovsky, simplicity, zoomed, transponder, subroutine, histone, nuisances, experimentation,
# Nearest to professional: jiao, buick, affiliates, practice, rejected, bikes, cadaver, sanctioned,
# Nearest to channel: compensates, bbc, rtp, railhead, filters, channels, relay, leandro,
# Nearest to governor: veto, folger, elbridge, litigants, vote, joplin, queen, cabinet,
# Nearest to frac: denominator, left, mathbf, neq, cos, sqrt, cdot, where,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9868 0.1886 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0967 0.1854 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0203 0.1848 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0328 0.1847 sec/batch
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7343 0.1894 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8408 0.1896 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7831 0.1967 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8296 0.1895 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8372 0.1908 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8537 0.1896 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8092 0.1893 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8669 0.1891 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9021 0.1896 sec/batch
# Nearest to five: two, zero, four, one, three, six, seven, eight,
# Nearest to of: the, in, and, is, see, a, on, by,
# Nearest to than: more, less, level, one, roughly, it, among, two,
# Nearest to up: come, synchronized, with, at, vayikra, ridiculous, silty, dumpling,
# Nearest to only: there, a, that, in, not, are, as, over,
# Nearest to after: until, last, was, continued, the, admission, he, wink,
# Nearest to s: of, nine, the, and, one, by, a, zero,
# Nearest to however: this, to, that, be, was, although, less, it,
# Nearest to report: archive, occurred, consensus, balanced, undertakes, hainan, solicit, discusses,
# Nearest to hit: catcher, hejira, blinking, disoriented, geometrically, ayman, run, wont,
# Nearest to universe: existence, bang, himalayas, diatessaron, wheeler, televison, extraterrestrials, flavour,
# Nearest to instance: zoomed, subroutine, loneliness, pantheons, such, velikovsky, popular, cmyk,
# Nearest to professional: buick, bikes, practice, jiao, agree, haitian, compete, rejected,
# Nearest to channel: bbc, compensates, railhead, channels, hedgehog, tak, co, leandro,
# Nearest to governor: folger, discovers, elbridge, dubnium, joplin, sandwich, furnishes, macgillivray,
# Nearest to frac: left, cos, denominator, dx, asking, sqrt, ebro, cdot,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8223 0.1919 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8794 0.1893 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8695 0.1885 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8457 0.1884 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8723 0.1879 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8572 0.1889 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8733 0.1885 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8356 0.1889 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8725 0.1895 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8381 0.1904 sec/batch
# Nearest to five: two, zero, one, four, three, six, seven, eight,
# Nearest to of: the, in, and, by, see, a, on, is,
# Nearest to than: less, more, one, level, two, roughly, mulroney, twenty,
# Nearest to up: come, shaking, with, two, dumpling, synchronized, silty, vayikra,
# Nearest to only: there, a, in, rivaled, not, over, that, several,
# Nearest to after: until, was, continued, the, last, he, admission, end,
# Nearest to s: of, nine, by, one, the, a, and, to,
# Nearest to however: was, to, although, be, less, this, that, exceed,
# Nearest to report: archive, occurred, consensus, balanced, hainan, solicit, undertakes, bab,
# Nearest to hit: hejira, catcher, blinking, ayman, disoriented, geometrically, wont, wherever,
# Nearest to universe: existence, himalayas, bang, diatessaron, wheeler, extraterrestrials, flavour, niels,
# Nearest to instance: zoomed, popular, such, subroutine, miscegenation, loneliness, leadbelly, velikovsky,
# Nearest to professional: buick, bikes, practice, agree, jiao, haitian, discipline, rejected,
# Nearest to channel: bbc, compensates, railhead, channels, hedgehog, co, tak, inhalation,
# Nearest to governor: folger, discovers, elbridge, bicameral, senator, sandwich, defying, acceptors,
# Nearest to frac: left, cos, denominator, cdot, sqrt, dx, mathbf, neq,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8600 0.1904 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8423 0.1877 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8194 0.1907 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8290 0.1889 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8962 0.1906 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8312 0.1915 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9740 0.1908 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9087 0.1903 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9238 0.1902 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8141 0.1896 sec/batch
# Nearest to five: two, zero, four, one, three, eight, seven, six,
# Nearest to of: the, in, and, by, see, for, on, from,
# Nearest to than: less, more, one, two, level, five, mulroney, among,
# Nearest to up: come, vayikra, shaking, synchronized, dumpling, with, family, two,
# Nearest to only: there, a, not, in, rivaled, are, result, several,
# Nearest to after: until, was, he, continued, the, returned, admission, his,
# Nearest to s: of, the, by, nine, and, one, to, a,
# Nearest to however: to, was, this, although, that, be, less, it,
# Nearest to report: archive, occurred, consensus, hainan, balanced, gallo, ogpu, bab,
# Nearest to hit: hejira, ayman, disoriented, blinking, catcher, geometrically, run, wont,
# Nearest to universe: himalayas, existence, diatessaron, bang, wheeler, mcduck, flavour, worlds,
# Nearest to instance: zoomed, subroutine, such, popular, miscegenation, loneliness, pantheons, leadbelly,
# Nearest to professional: buick, bikes, practice, agree, jiao, haitian, discipline, rejected,
# Nearest to channel: bbc, compensates, channels, railhead, stations, relay, inhalation, vocabularies,
# Nearest to governor: folger, discovers, elbridge, sandwich, senator, dubnium, teschen, defying,
# Nearest to frac: left, cos, denominator, sqrt, cdot, dx, mathbf, asking,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8084 0.1907 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8792 0.1888 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7968 0.1908 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8527 0.1882 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8447 0.1880 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8812 0.1888 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8969 0.1081 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8258 0.1879 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8228 0.1885 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8338 0.1896 sec/batch
# Nearest to five: two, one, zero, four, three, seven, six, eight,
# Nearest to of: the, and, in, a, by, on, see, as,
# Nearest to than: less, more, one, level, roughly, among, has, twenty,
# Nearest to up: come, with, synchronized, dalnet, vayikra, shaking, emphasize, silty,
# Nearest to only: there, a, in, not, several, addition, result, over,
# Nearest to after: until, was, the, continued, his, before, last, returned,
# Nearest to s: of, the, a, by, and, to, rest, zero,
# Nearest to however: to, this, that, be, less, was, although, exceed,
# Nearest to report: archive, occurred, balanced, hainan, consensus, ogpu, loschmidt, gallo,
# Nearest to hit: hejira, ayman, catcher, geometrically, blinking, disoriented, wont, heylin,
# Nearest to universe: existence, himalayas, diatessaron, flavour, bang, ludwig, wheeler, worlds,
# Nearest to instance: zoomed, popular, such, loneliness, velikovsky, colloid, subroutine, pantheons,
# Nearest to professional: buick, bikes, practice, agree, jiao, haitian, compete, dennis,
# Nearest to channel: bbc, compensates, channels, railhead, inhalation, tak, reelected, separatists,
# Nearest to governor: folger, discovers, elbridge, senator, defying, teschen, bicameral, dubnium,
# Nearest to frac: left, cos, denominator, cdot, dx, ebro, sqrt, asking,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8075 0.1903 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8185 0.1884 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8057 0.1894 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7955 0.1875 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8558 0.1867 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8363 0.1869 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8812 0.1877 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7437 0.1870 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8167 0.1862 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7674 0.1873 sec/batch
# Nearest to five: two, zero, four, one, three, seven, six, eight,
# Nearest to of: the, in, and, is, a, see, for, by,
# Nearest to than: more, less, one, two, level, has, five, among,
# Nearest to up: come, with, synchronized, at, dalnet, to, vayikra, two,
# Nearest to only: there, a, in, not, but, rivaled, that, first,
# Nearest to after: until, continued, last, was, returned, the, before, became,
# Nearest to s: of, the, by, a, one, nine, zero, rest,
# Nearest to however: this, was, be, to, less, that, exceed, it,
# Nearest to report: archive, occurred, balanced, hainan, consensus, ogpu, gallo, improves,
# Nearest to hit: hejira, catcher, geometrically, run, disoriented, ayman, blinking, bunt,
# Nearest to universe: existence, himalayas, bang, wheeler, niels, diatessaron, flavour, ludwig,
# Nearest to instance: such, zoomed, popular, leadbelly, subroutine, velikovsky, loneliness, astin,
# Nearest to professional: buick, bikes, practice, agree, jiao, haitian, compete, maintain,
# Nearest to channel: bbc, channels, compensates, programmes, railhead, inhalation, stations, hedgehog,
# Nearest to governor: folger, discovers, elbridge, bicameral, defying, furnishes, irreconcilable, vote,
# Nearest to frac: left, cos, denominator, cdot, dx, sqrt, where, ebro,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7830 0.1888 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8153 0.1866 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8424 0.1868 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8135 0.1877 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8375 0.1863 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9164 0.1879 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8412 0.1883 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7938 0.1874 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8256 0.1870 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8369 0.1885 sec/batch
# Nearest to five: two, zero, one, four, three, seven, six, eight,
# Nearest to of: the, in, and, is, see, a, for, by,
# Nearest to than: more, less, one, level, two, mulroney, five, among,
# Nearest to up: come, with, at, synchronized, vayikra, dwells, ridiculous, dalnet,
# Nearest to only: there, a, in, over, not, are, rivaled, that,
# Nearest to after: until, was, continued, last, returned, before, he, admission,
# Nearest to s: of, the, nine, one, and, a, by, two,
# Nearest to however: this, was, be, to, that, exceed, is, it,
# Nearest to report: archive, occurred, balanced, consensus, hainan, solicit, ogpu, constabulary,
# Nearest to hit: hejira, catcher, geometrically, ayman, blinking, disoriented, run, wont,
# Nearest to universe: existence, himalayas, bang, wheeler, worlds, diatessaron, mcduck, flavour,
# Nearest to instance: such, zoomed, popular, subroutine, loneliness, leadbelly, velikovsky, pantheons,
# Nearest to professional: buick, bikes, practice, agree, jiao, haitian, maintain, rejected,
# Nearest to channel: bbc, compensates, channels, inhalation, railhead, vocabularies, programmes, stations,
# Nearest to governor: folger, discovers, elbridge, bicameral, defying, sandwich, vote, furnishes,
# Nearest to frac: left, cos, denominator, sqrt, ebro, cdot, raises, where,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8563 0.1905 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8643 0.1872 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8095 0.1893 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8393 0.1878 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8919 0.1874 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8393 0.1886 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8216 0.1890 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8319 0.1895 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7990 0.1890 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8362 0.1885 sec/batch
# Nearest to five: two, one, four, zero, three, seven, six, eight,
# Nearest to of: the, in, and, by, on, for, a, to,
# Nearest to than: more, less, one, two, most, five, level, and,
# Nearest to up: come, two, at, with, together, the, synchronized, to,
# Nearest to only: there, a, in, not, are, on, several, which,
# Nearest to after: until, continued, was, returned, the, before, interrupted, last,
# Nearest to s: of, the, one, and, by, to, nine, two,
# Nearest to however: to, was, this, be, that, it, is, although,
# Nearest to report: archive, occurred, hainan, consensus, balanced, ogpu, constabulary, bab,
# Nearest to hit: hejira, geometrically, catcher, run, ayman, disoriented, blinking, wont,
# Nearest to universe: existence, himalayas, bang, wheeler, mcduck, worlds, diatessaron, flavour,
# Nearest to instance: such, zoomed, popular, leadbelly, loneliness, velikovsky, subroutine, colloid,
# Nearest to professional: buick, bikes, haitian, practice, agree, jiao, discipline, rejected,
# Nearest to channel: bbc, compensates, channels, inhalation, stations, vocabularies, hepatic, programmes,
# Nearest to governor: folger, discovers, bicameral, elbridge, sandwich, furnishes, vote, cabinet,
# Nearest to frac: left, cos, denominator, cdot, sqrt, ebro, fugue, neq,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8827 0.1922 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7994 0.1907 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9310 0.1895 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9115 0.1897 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8926 0.1893 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8346 0.1898 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7667 0.1890 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8366 0.1892 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7464 0.1894 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8420 0.1895 sec/batch
# Nearest to five: two, zero, one, four, three, seven, six, eight,
# Nearest to of: the, see, in, and, for, on, a, by,
# Nearest to than: more, less, among, two, has, level, one, most,
# Nearest to up: with, come, at, synchronized, vayikra, dalnet, together, emphasize,
# Nearest to only: there, in, a, are, not, several, addition, result,
# Nearest to after: until, continued, returned, was, he, admission, last, before,
# Nearest to s: the, of, zero, to, and, by, two, in,
# Nearest to however: was, to, that, be, it, this, although, less,
# Nearest to report: archive, occurred, consensus, hainan, balanced, gallo, constabulary, ogpu,
# Nearest to hit: hejira, geometrically, ayman, catcher, blinking, run, disoriented, wont,
# Nearest to universe: existence, himalayas, bang, mcduck, wheeler, ludwig, diatessaron, worlds,
# Nearest to instance: such, zoomed, popular, velikovsky, subroutine, colloid, leadbelly, loneliness,
# Nearest to professional: buick, bikes, haitian, practice, agree, jiao, discipline, rejected,
# Nearest to channel: bbc, compensates, channels, inhalation, railhead, stations, tak, separatists,
# Nearest to governor: folger, discovers, elbridge, bicameral, sandwich, dubnium, senator, teschen,
# Nearest to frac: left, cos, denominator, cdot, sqrt, ebro, fugue, neq,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8183 0.1927 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8175 0.1895 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
